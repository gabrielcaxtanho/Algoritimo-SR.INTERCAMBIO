# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielcaxtanho/Algoritimo-SR.INTERCAMBIO/blob/main/Algoritimo_SR_INTERCAMBIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algoritimo SR.INTERCAMBIO
#
# Auxilia no estudo com paginas em outros idiomas com a tradução possivel por fotos

# %%
##iMPORTANDO AS BIBLIOTECAS NECESSARIAS PARA FUNCIONAMENTO DO ALGORITIMO
import pytesseract
import numpy as np
import cv2 # OpenCV
from google.colab.patches import cv2_imshow # para mostrar as imagens no Google Colab

# %%
#Baixando as ferramentas necessarias para funcionamento do algoritimo
# !pip install opencv-python
# !sudo apt install tesseract-ocr
# !pip install pytesseract==0.3.9
# !pip install googletrans==4.0.0-rc1

# %%
##iMPORTANDO AS BIBLIOTECAS NECESSARIAS PARA FUNCIONAMENTO DO ALGORITIMO
from googletrans import Translator

# %%
#Baixando as ferramentas necessarias para funcionamento do algoritimo
# !apt-get install tesseract-ocr-por

# %%
# !mkdir tessdata

# %%
#Puxando do GITHUB versoes de idiomas ja prontas
# !wget -O ./tessdata/por.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true
# !wget -O ./tessdata/eng.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/eng.traineddata?raw=true

# %%
# !ls tessdata/

# %%
#Puxando a imagem e aplicando algumas propriedades para facilitar a leitura do aquivo
img = cv2.imread('/content/WhatsApp Image 2023-05-06 at 13.17.10 (1).jpeg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1600 at 0x7F83C0955120>

# %%
#Pedinfo ao OCR para fazer a verificação da imagem extraindo os caracteres
config_tesseract = '--tessdata-dir tessdata'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %%
config_tesseract = '--tessdata-dir tessdata --psm 6'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
texto_ingles = pytesseract.image_to_string(rgb, lang='eng', config=config_tesseract)

# Traduzir o texto do inglês para o português com a biblioteca googletrans
translator = Translator()
texto_traduzido = translator.translate(texto_ingles, dest='pt').text

# Imprimir o texto traduzido
print(texto_traduzido)
# Out:
# ||
# )
# Manual do usuário '
# Instrução |
# 1. ON/OFF
# (1) .PRESSE "ON/OFF ~ BUTTON depois de colocar esta Cale em um
# mesa plana.tire a capa de proteção contra bandeja.
# Exiba todos os Carereters.Então você pode pesar o objeto
# Depois de exibir "0" i |
# (ZF) F.KENress'BN/OFF'HUTTMM- A escala seria girada =
# desligado.e
# (3).Desligamento automático após um minuto wi
# 2. Zero e tare
# (1) .Se não exibir ~ 0 ~ após
# Botão "pegue" e ele vai
# o objeto na panela.
# (2) .Quando pesar o obje p53
# colocaria um contendo e
# exibir o peso de;
# ~ Botão "e eu
# valor padrão, l
# O peso do.B
# Contêiner, pl
# para wai normal
